# %%
from pandas import read_csv
companies = read_csv("MasterFile_Companies_SampleApril6.csv")
companies.head()
# Out:
#    CompanyID                                   CompanyNameDirty  \
# 0        NaN                                          EBAC, LLC
# 1        NaN                  Action Environmental Systems, LLC
# 2        NaN                                      CITY OF OLEAN
# 3        NaN  ST. LAWRENCE COUNTY Industrial Development Agency
# 4        NaN                             Paladin Group Holdings
#
#    CompanyNameClean                 CompanyAddress          City  \
# 0               NaN            5276 East Lake Road     Cazenovia
# 1               NaN          920 East 132nd Street         Bronx
# 2               NaN     100-500 North Union Street         Olean
# 3               NaN  Newton Falls + Carthage 13619  Newton Falls
# 4               NaN          39 Seminary Hill Road        Carmel
#
#           State    Zip DataSource
# 0       Madison  13035       REDC
# 1         Bronx  10454       REDC
# 2   Cattaraugus  14760       REDC
# 3  St. Lawrence  13666       REDC
# ...

# %%
companies['CompanyNameClean'] = companies['CompanyNameDirty'].str.replace(",","").str.replace(".","").str.replace("-","").str.upper()

# %%
companies
# Out:
#     CompanyID                                   CompanyNameDirty  \
# 0         NaN                                          EBAC, LLC
# 1         NaN                  Action Environmental Systems, LLC
# 2         NaN                                      CITY OF OLEAN
# 3         NaN  ST. LAWRENCE COUNTY Industrial Development Agency
# 4         NaN                             Paladin Group Holdings
# 5         NaN                    TECH VALLEY COMMUNICATIONS, INC
# 6         NaN                               Abel & Schafer, Inc.
# 7         NaN                                   Absara Audio LLC
# 8         NaN                           Ace Hardware Corporation
# 9         NaN                       Achieve Brand Integrity, LLC
# 10        NaN                                Acorda Therapeutics
# 11        NaN                    Addison Precision Manufacturing
# 12        NaN                                       LC Main, LLC
# ...
